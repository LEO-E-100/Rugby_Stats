# %%
# Import statements and creating the dataframe to be used.

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import linregress
# %matplotlib inline

df = pd.read_csv('Six_Nations_Results.csv')
df.fillna(0, inplace=True)
df.head()
# Out:
#    Index  Position    Nation  Won  Drawn  Lost  For  Against Diff  Tries  \
# 0      0         1   England    4      0     1  146       81   65     16
# 1      1         2   Ireland    3      0     2  126       77   49     14
# 2      2         3    France    3      0     2  107       90   17      8
# 3      3         4  Scotland    3      0     2  122      118    4     14
# 4      4         5     Wales    2      0     3  102       86   16      8
#
#    Table  Year
# 0     19  2017
# 1     14  2017
# 2     14  2017
# 3     14  2017
# 4     10  2017

# %%
Nations = ['England', 'Scotland', 'Wales', 'Ireland', 'Italy', 'France']

def total_tries(country):

    sum_tries = 0
    for i in df['Index']:
        for j in df['Nation']:
            if j == 'Wales':
                sum_tries += df.at[i, 'Tries']
            else:
                continue
    
    return sum_tries

print total_tries('Wales')
# Out:
# 16
# 0
# 14
# 1
# 8
# 2
# 14
# 3
# 8
# 4
# 6
# 5
# 13
# 6
# 17
# 7
# 15
# 8
# 11
# 9
# 7
# 10
# 8
# 11
# 8
# 12
# 18
# 13
# 13
# 14
# 9
# 15
# 8
# 16
# 6
# 17
# 16
# 18
# 14
# 19
# 11
# 20
# 9
# 21
# 4
# 22
# 7
# 23
# 9
# 24
# 5
# 25
# 7
# 26
# 5
# 27
# 5
# 28
# 6
# 29
# 297

# %%
df.at[i, 'Tries']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3a1f07946cbb> in <module>()
# ----> 1 df.at['Wales', 'Tries']
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1783                 raise ValueError('Invalid call for scalar access (getting)!')
#    1784
# -> 1785         key = self._convert_key(key)
#    1786         return self.obj.get_value(*key, takeable=self._takeable)
#    1787
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_key(self, key, is_setter)
#    1825             if ax.is_integer():
#    1826                 if not is_integer(i):
# -> 1827                     raise ValueError("At based indexing on an integer index "
#    1828                                      "can only have integer indexers")
#    1829             else:
#
# ValueError: At based indexing on an integer index can only have integer indexers
